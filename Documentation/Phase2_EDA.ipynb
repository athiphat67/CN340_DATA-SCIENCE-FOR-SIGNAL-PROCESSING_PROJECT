# %% [markdown]
# <a href="https://colab.research.google.com/github/athiphat67/CN240_DATA-SCIENCE-FOR-SIGNAL-PROCESSING_PROJECT/blob/athiphat-develop/Src/Phase2_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Phase 2 — Exploratory Data Analysis (EDA)
#
# # Section 1 : Load Raw Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. DATA ACQUISITION
# !gdown "https://drive.google.com/uc?id=19OS7gWyo29K2BJB1lCLbUAzs2DSgvKJF"
# !gdown "https://drive.google.com/uc?id=1M1jMN1x5WDw194aW-xwm-MG2PwpoxowA"
# !gdown "https://drive.google.com/uc?id=1jHfrf5uFe7VsBSzrToXSMDxOQGM2Sx_l"
# !gdown "https://drive.google.com/uc?id=1KK1XTzsCyje1Y2B2jY4S0UU4Mh33zAYQ"
print("✅ All datasets downloaded successfully.")

# 2. DATA LOADING
xauusd_df = pd.read_csv('XAUUSD_Daily_200406110000_202512310000.csv')
usdthb_df = pd.read_csv('USD_THB_2001-2026.csv')
vix_df    = pd.read_csv('VIX_History.csv')
gvz_df    = pd.read_csv('CBOE_Gold_Volatitity_Historical_Data.csv')

# Drop Vol. Colum
usdthb_df = usdthb_df.drop(columns=['Vol.'])
gvz_df    = gvz_df.drop(columns=['Vol.'])

print("")
print("✅ Raw data loaded successfully")
print(f"   XAU/USD : {xauusd_df.shape[0]:,} rows, {xauusd_df.shape[1]} columns")
print(f"   USD/THB : {usdthb_df.shape[0]:,} rows, {usdthb_df.shape[1]} columns")
print(f"   VIX     : {vix_df.shape[0]:,} rows, {vix_df.shape[1]} columns")
print(f"   GVZ     : {gvz_df.shape[0]:,} rows, {gvz_df.shape[1]} columns")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19OS7gWyo29K2BJB1lCLbUAzs2DSgvKJF
# To: /content/XAUUSD_Daily_200406110000_202512310000.csv
# 100% 299k/299k [00:00<00:00, 84.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1M1jMN1x5WDw194aW-xwm-MG2PwpoxowA
# To: /content/USD_THB_2001-2026.csv
# 100% 303k/303k [00:00<00:00, 104MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jHfrf5uFe7VsBSzrToXSMDxOQGM2Sx_l
# To: /content/VIX_History.csv
# 100% 466k/466k [00:00<00:00, 90.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KK1XTzsCyje1Y2B2jY4S0UU4Mh33zAYQ
# To: /content/CBOE_Gold_Volatitity_Historical_Data.csv
# 100% 189k/189k [00:00<00:00, 71.1MB/s]
# ✅ All datasets downloaded successfully.
#
# ✅ Raw data loaded successfully
#    XAU/USD : 5,538 rows, 8 columns
#    USD/THB : 6,374 rows, 6 columns
#    VIX     : 9,147 rows, 5 columns
#    GVZ     : 4,457 rows, 6 columns

# %% [markdown]
# ## Section 2 : Inspect Raw Data Structure & Metadata

# %% [markdown]
# ### Section 2.1 : Preview
# Column names, date format, value format

# %%
datasets = [("XAU/USD", xauusd_df, 'Close', 'Date'),
            ("USD/THB", usdthb_df, 'Close', 'Date'),
            ("VIX",     vix_df,    'Close', 'Date'),
            ("GVZ",     gvz_df,    'Close', 'Date')]

def preview_datasets(datasets):
    for name, df, col, date_col in datasets:
        print("=" * 60)
        print(f"{name} - First 5 rows")
        print("=" * 60)
        print(df.head())
        print()

preview_datasets(datasets)
# Out:
# ...
# XAU/USD - First 5 rows
# ...
#        <DATE>  <OPEN>  <HIGH>  <LOW>  <CLOSE>  <TICKVOL>  <VOL>  <SPREAD>
# 0  2004.06.11   384.0   384.8  382.8    384.1        303      0         0
# 1  2004.06.14   384.3   385.8  381.8    382.8       1954      0         0
# 2  2004.06.15   382.8   388.8  381.1    388.6       1995      0         0
# 3  2004.06.16   387.1   389.8  382.6    383.8       2106      0         0
# 4  2004.06.17   383.6   389.3  383.0    387.6       1638      0         0
#
# ...
# USD/THB - First 5 rows
# ...
#          Date   Price    Open    High     Low Change %
# 0  03/20/2026  32.855  32.470  32.960  32.425    1.19%
# 1  03/19/2026  32.470  32.785  32.955  32.390   -0.98%
# 2  03/18/2026  32.790  32.315  32.860  32.230    1.45%
# 3  03/17/2026  32.320  32.320  32.575  32.220    0.00%
# 4  03/16/2026  32.320  32.485  32.595  32.230   -0.40%
#
# ...
# VIX - First 5 rows
# ...
#          DATE   OPEN   HIGH    LOW  CLOSE
# 0  01/02/1990  17.24  17.24  17.24  17.24
# ...

# %% [markdown]
# ### Section 2.1.1 — Standardize Column Names, Date Format & Sort

# %%
xauusd_df = pd.read_csv('XAUUSD_Daily_200406110000_202512310000.csv')
usdthb_df = pd.read_csv('USD_THB_2001-2026.csv')
vix_df    = pd.read_csv('VIX_History.csv')
gvz_df    = pd.read_csv('CBOE_Gold_Volatitity_Historical_Data.csv')

usdthb_df = usdthb_df.drop(columns=['Vol.'])
gvz_df    = gvz_df.drop(columns=['Vol.'])

xauusd_df = standardize(xauusd_df,
    col_map     = {'<DATE>':'Date','<OPEN>':'Open','<HIGH>':'High','<LOW>':'Low','<CLOSE>':'Close'},
    date_format = '%Y.%m.%d')

usdthb_df = standardize(usdthb_df,
    col_map     = {'Date':'Date','Open':'Open','High':'High','Low':'Low','Price':'Close'},
    date_format = '%m/%d/%Y')

vix_df = standardize(vix_df,
    col_map     = {'DATE':'Date','OPEN':'Open','HIGH':'High','LOW':'Low','CLOSE':'Close'},
    date_format = '%m/%d/%Y')

gvz_df = standardize(gvz_df,
    col_map     = {'Date':'Date','Open':'Open','High':'High','Low':'Low','Price':'Close'},
    date_format = '%m/%d/%Y')

datasets = [("XAU/USD", xauusd_df), ("USD/THB", usdthb_df), ("VIX", vix_df), ("GVZ", gvz_df)]
verify_datasets(datasets)
# Out:
# ✅ Standardization complete
#
# Dataset    Start        End          Rows
# ...
# XAU/USD    2004-06-11   2025-12-31   5,538
# USD/THB    2001-09-14   2026-03-20   6,374
# VIX        1990-01-02   2026-03-20   9,147
# GVZ        2008-06-04   2026-02-27   4,457

# %% [markdown]
# ### After Standardization

# %%
def preview_datasets(datasets):
    for name, df in datasets:
        print("=" * 60)
        print(f"{name} - First 5 rows")
        print("=" * 60)
        print(df.head())
        print()

preview_datasets(datasets)
# Out:
# ...
# XAU/USD - First 5 rows
# ...
#         Date   Open   High    Low  Close
# 0 2004-06-11  384.0  384.8  382.8  384.1
# 1 2004-06-14  384.3  385.8  381.8  382.8
# 2 2004-06-15  382.8  388.8  381.1  388.6
# 3 2004-06-16  387.1  389.8  382.6  383.8
# 4 2004-06-17  383.6  389.3  383.0  387.6
#
# ...
# USD/THB - First 5 rows
# ...
#         Date   Open    High    Low   Close
# 0 2001-09-14  44.15  44.325  44.00  44.135
# 1 2001-09-17  44.10  44.150  43.91  44.000
# 2 2001-09-18  44.00  44.330  44.00  44.150
# 3 2001-09-19  44.10  44.290  44.07  44.170
# 4 2001-09-20  44.15  44.380  44.09  44.140
#
# ...
# VIX - First 5 rows
# ...
#         Date   Open   High    Low  Close
# 0 1990-01-02  17.24  17.24  17.24  17.24
# 1 1990-01-03  18.19  18.19  18.19  18.19
# 2 1990-01-04  19.22  19.22  19.22  19.22
# 3 1990-01-05  20.11  20.11  20.11  20.11
# 4 1990-01-08  20.26  20.26  20.26  20.26
#
# ...
# GVZ - First 5 rows
# ...
#         Date   Open   High    Low  Close
# 0 2008-06-04  22.69  22.69  22.69  22.69
# ...

# %% [markdown]
# ### Section 2.2 : Schema
# Data types per column

# %%
def schema_datasets(datasets):
    for name, df in datasets:
        print("=" * 60)
        print(f"{name} - Schema")
        print("=" * 60)
        print(df.dtypes)
        print()

schema_datasets(datasets)
# Out:
# ...
# XAU/USD - Schema
# ...
# Date     datetime64[ns]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object
#
# ...
# USD/THB - Schema
# ...
# Date     datetime64[ns]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object
#
# ...
# VIX - Schema
# ...
# Date     datetime64[ns]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object
#
# ...
# GVZ - Schema
# ...
# Date     datetime64[ns]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object

# %% [markdown]
# ### Section 2.3.1 — Basic Statistics
#
# Compute count, mean, std, min, and max for the close price of each dataset.
#
# Goal: spot impossible values such as negative prices or zero readings.

# %%
def basic_stats(datasets):
    for name, df, col, date_col in datasets:
        print("=" * 60)
        print(f"{name} — Basic Statistics")
        print("=" * 60)
        display(df[[col]].describe().round(4))
        print()

basic_stats(datasets)
# Out:
# ...
# XAU/USD — Basic Statistics
# ...
#            Close
# count  5538.0000
# mean   1415.3121
# std     668.3622
# min     382.8000
# 25%    1064.7400
# 50%    1302.4350
# 75%    1749.6025
# max    4533.3200
# ...
# USD/THB — Basic Statistics
# ...
#            Close
# count  6374.0000
# mean     34.5688
# std       3.8028
# min      28.6150
# 25%      31.6900
# 50%      33.3800
# 75%      36.1100
# max      44.8800
# ...
# VIX — Basic Statistics
# ...
#            Close
# count  9147.0000
# mean     19.4492
# std       7.7615
# min       9.1400
# 25%      13.9500
# 50%      17.6000
# 75%      22.7300
# max      82.6900
# ...
# GVZ — Basic Statistics
# ...
#            Close
# count  4457.0000
# mean     18.7004
# std       6.8725
# min       8.8800
# 25%      14.8200
# 50%      17.2900
# 75%      20.8500
# max      64.5300

# %% [markdown]
# ### Section 2.3.2 — Outlier Detection
# Method: IQR (numeric summary) + Boxplot (visual)

# %%
def outlier_detection(datasets):
    print("=" * 60)
    print("Outlier Detection (IQR Method)")
    print("=" * 60)

    for name, df, col, date_col in datasets:
        Q1  = df[col].quantile(0.25)
        Q3  = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower    = Q1 - 1.5 * IQR
        upper    = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower) | (df[col] > upper)]
        flag     = "⚠️" if len(outliers) > 0 else "✅"

        print(f"\n{flag} {name}")
        print(f"   Lower bound : {lower:.4f}")
        print(f"   Upper bound : {upper:.4f}")
        print(f"   Outliers    : {len(outliers)} rows ({len(outliers)/len(df)*100:.2f}%)")

        if len(outliers) > 0:
            print(outliers[[date_col, col]].head(3).to_string(index=False))

outlier_detection(datasets)
# Out:
# ...
# Outlier Detection (IQR Method)
# ...
#
# ⚠️ XAU/USD
#    Lower bound : 37.4462
#    Upper bound : 2776.8963
#    Outliers    : 239 rows (4.32%)
#       Date   Close
# 2024-10-30 2787.21
# 2025-01-30 2794.06
# 2025-01-31 2798.47
#
# ⚠️ USD/THB
#    Lower bound : 25.0600
#    Upper bound : 42.7400
#    Outliers    : 318 rows (4.99%)
#       Date  Close
# 2001-09-14 44.135
# 2001-09-17 44.000
# 2001-09-18 44.150
#
# ⚠️ VIX
#    Lower bound : 0.7800
#    Upper bound : 35.9000
#    Outliers    : 322 rows (3.52%)
#       Date  Close
# 1990-08-06  35.91
# 1990-08-23  36.47
# 1991-01-14  36.20
#
# ⚠️ GVZ
#    Lower bound : 5.7750
#    Upper bound : 29.8950
#    Outliers    : 254 rows (5.70%)
#       Date  Close
# 2008-07-11  33.32
# 2008-07-14  31.09
# 2008-07-15  30.40

# %%
COLORS = {'XAU/USD': '#D4A017', 'USD/THB': '#185FA5', 'VIX': '#A32D2D', 'GVZ': '#2D7A2D'}

def plot_boxplot(datasets, colors=COLORS):
    fig, axes = plt.subplots(1, len(datasets), figsize=(24, 4))

    for ax, (name, df, col, date_col) in zip(axes, datasets):
        sns.boxplot(x=df[col], ax=ax, color=colors[name])
        ax.set_title(f"{name} — Boxplot")
        ax.set_xlabel("Price")

    plt.suptitle("Section 2.3.2 : Outlier Detection (IQR + Boxplot)", fontsize=15, y=1.02)
    plt.tight_layout()
    plt.savefig("Boxplot.png", dpi=300, bbox_inches='tight')
    plt.show()

plot_boxplot(datasets)

# %% [markdown]
# ### Section 2.3.3 — Distribution Shape (Skewness & Kurtosis)
#
# | Metric | Interpretation |
# |--------|---------------|
# | Skewness = 0 | Symmetric distribution |
# | Skewness > 0 | Right-skewed — long right tail |
# | Skewness < 0 | Left-skewed — long left tail |
# | Kurtosis ~ 3 | Normal distribution |
# | Kurtosis > 3 | Fat tails — extreme events are more likely than normal |
#
# Financial data typically shows high kurtosis (fat tails),
# meaning large price swings occur more often than a normal
# distribution would predict.

# %%
def skewness_kurtosis(datasets):
    print("=" * 60)
    print("Distribution Shape — Skewness & Kurtosis")
    print("=" * 60)

    for name, df, col, date_col in datasets:
        skew = df[col].skew()
        kurt = df[col].kurt()

        skew_flag = "⚠️  right-skewed"       if skew >  1 else \
                    "⚠️  left-skewed"         if skew < -1 else \
                    "✅  approx. symmetric"

        kurt_flag = "⚠️  fat tails — extreme events likely" if kurt > 1 else \
                    "✅  normal tails (excess kurtosis)"

        print(f"\n{name}")
        print(f"   Skewness : {skew:+.4f}  →  {skew_flag}")
        print(f"   Kurtosis : {kurt:+.4f}  →  {kurt_flag}")

skewness_kurtosis(datasets)
# Out:
# ...
# Distribution Shape — Skewness & Kurtosis
# ...
#
# XAU/USD
#    Skewness : +1.3470  →  ⚠️  right-skewed
#    Kurtosis : +3.2839  →  ⚠️  fat tails — extreme events likely
#
# USD/THB
#    Skewness : +0.9725  →  ✅  approx. symmetric
#    Kurtosis : -0.0310  →  ✅  normal tails (excess kurtosis)
#
# VIX
#    Skewness : +2.2046  →  ⚠️  right-skewed
#    Kurtosis : +8.6889  →  ⚠️  fat tails — extreme events likely
#
# GVZ
#    Skewness : +2.2052  →  ⚠️  right-skewed
#    Kurtosis : +7.2953  →  ⚠️  fat tails — extreme events likely

# %% [markdown]
# ### Section 2.3.4 — Distribution of raw close price per dataset
# Method: Histogram + KDE + Rug (combined) as per lecture slides

# %%
fig, axes = plt.subplots(1, 4, figsize=(24, 5))  # ← 4 subplots

for ax, (name, df, col, date_col) in zip(axes, datasets):  # ← unpack 4 ค่า
    sns.histplot(df[col], kde=True, bins=80, stat='density',
                 ax=ax, color=COLORS[name], alpha=0.5)
    sns.rugplot(df[col], ax=ax, color=COLORS[name], height=0.03, alpha=0.3)
    ax.set_title(f"{name} — Distribution")
    ax.set_xlabel("Price")
    ax.set_ylabel("Density")

plt.suptitle("Section 2.3.4 : Raw Price Distributions (Histogram + KDE + Rug)",
             fontsize=15, y=1.02)
plt.tight_layout()
plt.savefig("Raw_Price_Distributions(Histogram+KDE+Rug).png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Section 2.3.5 — Raw price trends over time
# Method: Line plot as per lecture slides
#
# Goal : verify date range and spot anomalies (e.g. USD/THB spike)

# %%
def plot_price_trends(datasets, colors=COLORS):
    fig, axes = plt.subplots(len(datasets), 1, figsize=(16, 4 * len(datasets)))

    for ax, (name, df, col, date_col) in zip(axes, datasets):
        step    = max(1, len(df) // 2000)
        df_plot = df.iloc[::step]

        ax.plot(df_plot[date_col], df_plot[col], linewidth=0.8, color=colors[name])
        ax.set_title(f"{name} — Price over Time")
        ax.set_xlabel("Date")
        ax.set_ylabel("Price")

    plt.suptitle("Section 2.3.5 : Raw Price Trends (Line Plot)", fontsize=15, y=1.02)
    plt.tight_layout()
    plt.savefig("Raw_Price_Trends(Line_Plot).png", dpi=300)
    plt.show()

plot_price_trends(datasets)

# %% [markdown]
# ### Section 2.4 — Missing Values
# Goal: know data quality before merging

# %%
def missing_values(datasets):
    print("Missing values per column\n")

    for name, df, col, date_col in datasets:
        missing = df.isnull().sum()
        total   = len(df)

        print("=" * 40)
        print(f"{name}")
        print("=" * 40)

        for c in df.columns:
            count = missing[c]
            pct   = count / total * 100
            flag  = " ⚠️" if count > 0 else " ✅"
            print(f"  {c:<20} {count:>5} missing ({pct:.1f}%){flag}")

        print()

missing_values(datasets)
# Out:
# Missing values per column
#
# ...
# XAU/USD
# ...
#   Date                     0 missing (0.0%) ✅
#   Open                     0 missing (0.0%) ✅
#   High                     0 missing (0.0%) ✅
#   Low                      0 missing (0.0%) ✅
#   Close                    0 missing (0.0%) ✅
#
# ...
# USD/THB
# ...
#   Date                     0 missing (0.0%) ✅
#   Open                     0 missing (0.0%) ✅
#   High                     0 missing (0.0%) ✅
#   Low                      0 missing (0.0%) ✅
#   Close                    0 missing (0.0%) ✅
#
# ...
# VIX
# ...
#   Date                     0 missing (0.0%) ✅
#   Open                     0 missing (0.0%) ✅
#   High                     0 missing (0.0%) ✅
#   Low                      0 missing (0.0%) ✅
#   Close                    0 missing (0.0%) ✅
#
# ...
# GVZ
# ...
#   Date                     0 missing (0.0%) ✅
#   Open                     0 missing (0.0%) ✅
#   High                     0 missing (0.0%) ✅
#   Low                      0 missing (0.0%) ✅
# ...

# %% [markdown]
# # Section 3 — Stationarity Test (ADF)

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series, name):
    result  = adfuller(series.dropna())
    p_value = result[1]
    stat    = result[0]
    flag    = "❌ Non-stationary → transformation required" if p_value > 0.05 else "✅ Stationary"

    print(f"{name}")
    print(f"   ADF Statistic : {stat:.4f}")
    print(f"   p-value       : {p_value:.6f}")
    print(f"   Result        : {flag}")
    print()

def run_adf_test(datasets):
    # --- 3.1 Raw Close Price ---
    print("=" * 60)
    print("Section 3.1 — ADF Test on Raw Close Price")
    print("=" * 60)
    print()

    for name, df, col, date_col in datasets:
        adf_test(df[col], name)

    # --- 3.2 After Log Return ---
    print("=" * 60)
    print("Section 3.2 — ADF Test after Log Return Transformation")
    print("=" * 60)
    print()

    for name, df, col, date_col in datasets:
        log_return = np.log(df[col] / df[col].shift(1)).dropna()
        adf_test(log_return, f"{name} (log return)")

run_adf_test(datasets)
# Out:
# ...
# Section 3.1 — ADF Test on Raw Close Price
# ...
#
# XAU/USD
#    ADF Statistic : 3.5383
#    p-value       : 1.000000
#    Result        : ❌ Non-stationary → transformation required
#
# USD/THB
#    ADF Statistic : -2.5577
#    p-value       : 0.102051
#    Result        : ❌ Non-stationary → transformation required
#
# VIX
#    ADF Statistic : -7.2667
#    p-value       : 0.000000
#    Result        : ✅ Stationary
#
# GVZ
#    ADF Statistic : -3.9314
#    p-value       : 0.001816
#    Result        : ✅ Stationary
#
# ...
# Section 3.2 — ADF Test after Log Return Transformation
# ...
#
# XAU/USD (log return)
#    ADF Statistic : -74.4390
#    p-value       : 0.000000
#    Result        : ✅ Stationary
#
# USD/THB (log return)
#    ADF Statistic : -13.5249
#    p-value       : 0.000000
#    Result        : ✅ Stationary
#
# VIX (log return)
#    ADF Statistic : -33.6796
#    p-value       : 0.000000
#    Result        : ✅ Stationary
#
# GVZ (log return)
#    ADF Statistic : -20.1666
# ...
